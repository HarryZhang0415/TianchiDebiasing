# %%
import pandas as pd


test_qtime = 'underexpose_test_qtime-0.csv'
test_click = 'underexpose_test_click-0.csv'

# %%
path = '../data/underexpose_test/underexpose_test_click-0/'

test_qtime = pd.read_csv(path + test_qtime, header=None)
test_click = pd.read_csv(path + test_click, header=None)

# %%
test_qtime.columns = ['user_id', 'query_time']
test_click.columns = ['user_id', 'item_id', 'time']

# %%
test_qtime.head()
# Out:
#    user_id  query_time
# 0       11    0.983869
# 1       22    0.983956
# 2       44    0.983924
# 3       55    0.983953
# 4       66    0.983895

# %%
test_click[test_click['user_id']==1133].sort_values('time',ascending=True)
# Out:
#        user_id  item_id      time
# 15807     1133    87266  0.983790
# 549       1133   104098  0.983791
# 5368      1133    44994  0.983791
# 5247      1133    20158  0.983796
# 2512      1133      255  0.983796
# 663       1133     9782  0.983811
# 20848     1133    45861  0.983811
# 3286      1133    20994  0.983811
# 0         1133      221  0.983812
# 16224     1133    40563  0.983812
# 6557      1133    26645  0.983812
# 4513      1133    11025  0.983812
# 1734      1133    85790  0.983812
# 15320     1133   114555  0.983812
# 2977      1133    87433  0.983812
# 1224      1133   112859  0.983812
# 9481      1133   102761  0.983813
# 10614     1133    81626  0.983813
# 17111     1133    76445  0.983813
# 14274     1133    46930  0.983814
# 19477     1133    23623  0.983819
# 18591     1133   107772  0.983819
# 16248     1133    44764  0.983819
# 12361     1133    44298  0.983819
# 19604     1133    50808  0.983820
# 602       1133   114268  0.983820
# ...

# %%
test_qtime[test_qtime['user_id']==1133]
# Out:
#     user_id  query_time
# 61     1133    0.983953
